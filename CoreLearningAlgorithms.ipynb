# %% [markdown]
# * Linear Regression
# * Classification
# * Clustering
# * Hidden Markov Models

# %% [markdown]
# ### Linear Regression

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
print()

plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])

plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %%
import sklearn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc

import tensorflow as tf

dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv') # training data
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv') # testing data
y_train = dftrain.pop('survived')
y_eval = dfeval.pop('survived')
print(dftrain.head())
print(dftrain.describe())
print(dftrain.shape)
dftrain.age.hist(bins=20)
# Out:
#       sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0    male  22.0                   1      0   7.2500  Third  unknown
# 1  female  38.0                   1      0  71.2833  First        C
# 2  female  26.0                   0      0   7.9250  Third  unknown
# 3  female  35.0                   1      0  53.1000  First        C
# 4    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y
#               age  n_siblings_spouses       parch        fare
# count  627.000000          627.000000  627.000000  627.000000
# mean    29.631308            0.545455    0.379585   34.385399
# std     12.511818            1.151090    0.792999   54.597730
# min      0.750000            0.000000    0.000000    0.000000
# 25%     23.000000            0.000000    0.000000    7.895800
# 50%     28.000000            0.000000    0.000000   15.045800
# 75%     35.000000            1.000000    0.000000   31.387500
# max     80.000000            8.000000    5.000000  512.329200
# (627, 9)
# <AxesSubplot:>

# %%
dftrain.sex.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
dftrain['class'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
pd.concat([dftrain, y_train], axis=1).groupby('sex').survived.mean().plot(kind='barh').set_xlabel('% survive')
# Out:
# Text(0.5, 0, '% survive')

# %%
# Categorical/Numeric Columns
CATEGORICAL_COLUMNS = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
NUMERIC_COLUMNS = ['age', 'fare']

feature_columns = []

for feature_name in CATEGORICAL_COLUMNS:
    vocabulary = dftrain[feature_name].unique()
    print(vocabulary)
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

for c in feature_columns:
    print(c)
# Out:
# ['male' 'female']
# [1 0 3 4 2 5 8]
# [0 1 2 5 3 4]
# ['Third' 'First' 'Second']
# ['unknown' 'C' 'G' 'A' 'B' 'D' 'F' 'E']
# ['Southampton' 'Cherbourg' 'Queenstown' 'unknown']
# ['n' 'y']
# VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0)
# VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0)
# VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0)
# VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0)
# VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0)
# VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0)
# VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0)
# NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
# NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %%
# Input Function converts pandas dataframe to tf.data.Dataset
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    return input_function

train_input_fn = make_input_fn(dftrain, y_train)
eval_input_fn = make_input_fn(dfeval, y_eval)

# %%
# Create the model
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
print(linear_est)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Andreas\AppData\Local\Temp\tmpq6e70fsp
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Andreas\\AppData\\Local\\Temp\\tmpq6e70fsp', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# <tensorflow_estimator.python.estimator.canned.linear.LinearClassifierV2 object at 0x000001E40FC54668>

# %%
# Train the model
linear_est.train(train_input_fn)
result = linear_est.evaluate(eval_input_fn)
clear_output()
print(result['accuracy'])
# Out:
# 0.7348485

# %%
pred_dicts = list(linear_est.predict(eval_input_fn))
print(pred_dicts)
probs = pd.Series([pred['probabilities'][1] for pred in pred_dicts])

probs.plot(kind='hist', bins=20, title='predicted probabilities')
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Andreas\AppData\Local\Temp\tmpq6e70fsp\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([-2.1553574], dtype=float32), 'logistic': array([0.10383166], dtype=float32), 'probabilities': array([0.89616835, 0.10383166], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-2.0751987], dtype=float32), 'logistic': array([0.11153085], dtype=float32), 'probabilities': array([0.88846916, 0.11153086], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-0.5187783], dtype=float32), 'logistic': array([0.37313795], dtype=float32), 'probabilities': array([0.62686205, 0.37313795], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-0.21719289], dtype=float32), 'logistic': array([0.44591424], dtype=float32), 'probabilities': array([0.5540858 , 0.44591424], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([1.8853415], dtype=float32), 'logistic': array([0.8682234], dtype=float32), 'probabilities': array([0.13177653, 0.8682234 ], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-2.3453646], dtype=float32), 'logistic': array([0.08743493], dtype=float32), 'probabilities': array([0.91256505, 0.08743492], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-3.1330795], dtype=float32), 'logistic': array([0.04176319], dtype=float32), 'probabilities': array([0.9582368 , 0.04176319], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([0.72465074], dtype=float32), 'logistic': array([0.67363036], dtype=float32), 'probabilities': array([0.3263697 , 0.67363036], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-2.0141273], dtype=float32), 'logistic': array([0.11772761], dtype=float32), 'probabilities': array([0.8822724 , 0.11772762], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([3.0330763], dtype=float32), 'logistic': array([0.95404625], dtype=float32), 'probabilities': array([0.04595377, 0.95404625], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-0.35034907], dtype=float32), 'logistic': array([0.41329777], dtype=float32), 'probabilities': array([0.5867022 , 0.41329777], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-1.9840193], dtype=float32), 'logistic': array([0.12089104], dtype=float32), 'probabilities': array([0.87910897, 0.12089103], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1]), 'all_classes': array([b'0', b'1'], dtype=object)}, {'logits': array([-1.3042325], dtype=float32), 'logistic': array([0.21345356], dtype=float32), 'probabilities': array([0.7865464 , 0.21345356], dtyp ...
# <AxesSubplot:title={'center':'predicted probabilities'}, ylabel='Frequency'>

# %% [markdown]
# ### Classification

# %%
# Dataset: Classify flowers in 3 species
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

train_y = train.pop('Species')
test_y = test.pop('Species')
print(train.head())
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
# Input function

def input_fn(features, labels, training=True, bathc_size=256):
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    if training:
        dataset = dataset.shuffle(1000).repeat()
    return dataset.batch(bathc_size)

# %%
# Feature Columns
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
# Build The model
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    hidden_units=[30, 10],
    n_classes=3
)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Andreas\AppData\Local\Temp\tmpjeo2gnky
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Andreas\\AppData\\Local\\Temp\\tmpjeo2gnky', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# INFO:tensorflow:global_step/sec: 349.586
# INFO:tensorflow:loss = 0.25127202, step = 9700 (0.279 sec)
# INFO:tensorflow:global_step/sec: 381.461
# INFO:tensorflow:loss = 0.24230713, step = 9800 (0.262 sec)
# INFO:tensorflow:global_step/sec: 383.004
# INFO:tensorflow:loss = 0.25894216, step = 9900 (0.261 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Users\Andreas\AppData\Local\Temp\tmpjeo2gnky\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.22664067.

# %%
# Evaluate the model
res = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False)
)
print(res)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-30T11:04:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Andreas\AppData\Local\Temp\tmpjeo2gnky\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.37100s
# INFO:tensorflow:Finished evaluation at 2020-08-30-11:04:23
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.96666664, average_loss = 0.27001056, global_step = 10000, loss = 0.27001056
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: C:\Users\Andreas\AppData\Local\Temp\tmpjeo2gnky\model.ckpt-10000
# {'accuracy': 0.96666664, 'average_loss': 0.27001056, 'loss': 0.27001056, 'global_step': 10000}

# %%
# Predictions
def input_fn_pred(features, batch_size=256):
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size=batch_size)

features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
predict = {}

print("Please type numeric values as prompted.")
for feature in features:
  valid = True
  while valid:
    val = input(feature + ": ")
    if not val.isdigit(): valid = False

  predict[feature] = [float(val)]

predictions = classifier.predict(input_fn=lambda: input_fn_pred(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]
    print('Prediction is {} ({:.2f}%)'.format(SPECIES[class_id], 100*probability))
# Out:
# Please type numeric values as prompted.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Andreas\AppData\Local\Temp\tmpjeo2gnky\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is Setosa (48.49%)

# %% [markdown]
# ### Clustering

# %%
# K means clustering

# %% [markdown]
# ### Hidden Markov Models

# %%
# !pip install tensorflow_probability==0.8.0rc0 --user --upgrade
# Out:
# Requirement already up-to-date: tensorflow_probability==0.8.0rc0 in c:\users\andreas\appdata\roaming\python\python36\site-packages (0.8.0rc0)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\andreas\anaconda3\envs\freecodecamptf\lib\site-packages (from tensorflow_probability==0.8.0rc0) (4.4.2)
# Requirement already satisfied, skipping upgrade: cloudpickle==1.1.1 in c:\users\andreas\appdata\roaming\python\python36\site-packages (from tensorflow_probability==0.8.0rc0) (1.1.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\andreas\anaconda3\envs\freecodecamptf\lib\site-packages (from tensorflow_probability==0.8.0rc0) (1.19.1)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in c:\users\andreas\anaconda3\envs\freecodecamptf\lib\site-packages (from tensorflow_probability==0.8.0rc0) (1.15.0)

# %%
import tensorflow_probability as tfp  # We are using a different module from tensorflow this time
import tensorflow as tf

# %%
tfd = tfp.distributions
initial_distribution = tfd.Categorical(probs=[0.2, 0.8])
transition_distribution = tfd.Categorical(probs=[[0.5, 0.5],[0.2, 0.8]])
observation_distribution = tfd.Normal(loc=[0., 15.], scale=[5., 10.])

# %%
model = tfd.HiddenMarkovModel(
    initial_distribution=initial_distribution,
    transition_distribution=transition_distribution,
    observation_distribution=observation_distribution,
    num_steps=7
)

# %%
mean = model.mean()
with tf.compat.v1.Session():
    print(mean.numpy())
# Out:
# [12.       11.1      10.83     10.748999 10.724698 10.71741  10.715222]
